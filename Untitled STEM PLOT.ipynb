# %% [markdown]
# ***STEM PLOT***

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60]
y=[20,40,70,50,20,10]
plt.title("STEM PLOT")
plt.stem(x,y,linefmt=":",bottom=0,markerfmt="r*",basefmt="g")
plt.show()
