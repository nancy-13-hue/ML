# %% [markdown]
# ***STEP PLOT***

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,5,7,9,0,1]
plt.step(x,y,marker="*",color="hotpink",ms=10,mfc="m",label="Marks")
plt.grid()
plt.legend(loc=2)
plt.show()
