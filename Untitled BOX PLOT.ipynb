# %% [markdown]
# ***BOX PLOT***

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70,120]
x1=[20,30,70,50,90,130,20,30,150]
z=[x,x1]
plt.title("BOX PLOT")
plt.boxplot(z,labels=["marks","score"],showmeans=True,patch_artist=True)
plt.grid()
plt.show()
